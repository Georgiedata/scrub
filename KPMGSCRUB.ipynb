# %%
import pandas as pd

KPMG_Tran = pd.read_excel(r"C:/Users/George/Downloads/data4P/KPMG_Transactions.xlsx", header = None)
KPMG_Tran
# Out:
#                                                       0           1   \
# 0      Note: The data and information in this documen...         NaN
# 1                                         transaction_id  product_id
# 2                                                      1           2
# 3                                                      2           3
# 4                                                      3          37
# ...                                                  ...         ...
# 19997                                              19996          51
# 19998                                              19997          41
# 19999                                              19998          87
# 20000                                              19999           6
# 20001                                              20000          11
#
#                 2                    3             4             5   \
# 0              NaN                  NaN           NaN           NaN
# ...

# %%
KPMG_Tran.drop(KPMG_Tran.index[0], axis = 0, inplace = True)
KPMG_Tran
# Out:
#                    0           1            2                    3   \
# 1      transaction_id  product_id  customer_id     transaction_date
# 2                   1           2         2950  2017-02-25 00:00:00
# 3                   2           3         3120  2017-05-21 00:00:00
# 4                   3          37          402  2017-10-16 00:00:00
# 5                   4          88         3135  2017-08-31 00:00:00
# ...               ...         ...          ...                  ...
# 19997           19996          51         1018  2017-06-24 00:00:00
# 19998           19997          41          127  2017-11-09 00:00:00
# 19999           19998          87         2284  2017-04-14 00:00:00
# 20000           19999           6         2764  2017-07-03 00:00:00
# 20001           20000          11         1144  2017-09-22 00:00:00
#
#                  4             5               6             7   \
# 1      online_order  order_status           brand  product_line
# ...

# %%
KPMG_Tran.isnull().sum().sum()
# Out:
# 1542

# %%
KPMG_Tran.columns = KPMG_Tran.iloc[0]

KPMG_Tran
# Out:
# 1      transaction_id  product_id  customer_id     transaction_date  \
# 1      transaction_id  product_id  customer_id     transaction_date
# 2                   1           2         2950  2017-02-25 00:00:00
# 3                   2           3         3120  2017-05-21 00:00:00
# 4                   3          37          402  2017-10-16 00:00:00
# 5                   4          88         3135  2017-08-31 00:00:00
# ...               ...         ...          ...                  ...
# 19997           19996          51         1018  2017-06-24 00:00:00
# 19998           19997          41          127  2017-11-09 00:00:00
# 19999           19998          87         2284  2017-04-14 00:00:00
# 20000           19999           6         2764  2017-07-03 00:00:00
# 20001           20000          11         1144  2017-09-22 00:00:00
#
# 1      online_order  order_status           brand  product_line  \
# 1      online_order  order_status           brand  product_line
# ...

# %%
KPMG_Tran.drop(index = 1, axis = 0, inplace = True)

# %%
KPMG_Tran.set_index('transaction_id', inplace = True )
# Out:
# C:\Users\George\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6999: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)

# %%
KPMG_Tran.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 20000 entries, (1, 2) to (20000, 11)
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customer_id              20000 non-null  object
#  1   transaction_date         20000 non-null  object
#  2   online_order             19640 non-null  object
#  3   order_status             20000 non-null  object
#  4   brand                    19803 non-null  object
#  5   product_line             19803 non-null  object
#  6   product_class            19803 non-null  object
#  7   product_size             19803 non-null  object
#  8   list_price               20000 non-null  object
#  9   standard_cost            19803 non-null  object
#  10  product_first_sold_date  19803 non-null  object
# dtypes: object(11)
# memory usage: 2.4+ MB

# %%
KPMG_Tran.describe().all()
# Out:
# 1
# customer_id                True
# transaction_date           True
# online_order               True
# order_status               True
# brand                      True
# product_line               True
# product_class              True
# product_size               True
# list_price                 True
# standard_cost              True
# product_first_sold_date    True
# dtype: bool

# %%
KPMG_Tran.head()
# Out:
# 1              product_id customer_id     transaction_date online_order  \
# transaction_id
# 1                       2        2950  2017-02-25 00:00:00        False
# 2                       3        3120  2017-05-21 00:00:00         True
# 3                      37         402  2017-10-16 00:00:00        False
# 4                      88        3135  2017-08-31 00:00:00        False
# 5                      78         787  2017-10-01 00:00:00         True
#
# 1              order_status           brand product_line product_class  \
# transaction_id
# 1                  Approved           Solex     Standard        medium
# 2                  Approved   Trek Bicycles     Standard        medium
# 3                  Approved      OHM Cycles     Standard           low
# 4                  Approved  Norco Bicycles     Standard        medium
# 5                  Approved  Giant Bicycles     Standard        medium
#
# ...

# %%
KPMG_Tran.isna().any()
# Out:
# 1
# product_id                 False
# customer_id                False
# transaction_date           False
# online_order                True
# order_status               False
# brand                       True
# product_line                True
# product_class               True
# product_size                True
# list_price                 False
# standard_cost               True
# product_first_sold_date     True
# dtype: bool

# %%
KPMG_Tran['standard_cost'].median()
# Out:
# 507.58

# %%
import seaborn as sns
sns.distplot(KPMG_Tran['standard_cost'])

sns.distplot(KPMG_Tran['standard_cost'])
#Since the distribution is right skewed, replace the 'NaN' cells of the standard cost with the median.
# Out:
# C:\Users\George\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\George\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='standard_cost', ylabel='Density'>

# %%
KPMG_Tran['standard_cost'] = KPMG_Tran['standard_cost'].fillna(507.58)

# %%
KPMG_Tran['standard_cost'].isnull().sum().sum()
# Out:
# 0

# %%
KPMG_Trs = KPMG_Tran.to_csv('C:/Users/George/Downloads/data4P/Transation_C.csv')
KPMG_Trs

# %%
KPMG_cus = pd.read_excel(r"C:/Users/George/Downloads/data4P/Customer_list.xlsx")
KPMG_cus
# Out:
# C:\Users\George\AppData\Local\Temp\ipykernel_12928\587416772.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   KPMG_cus = pd.read_excel(r"C:/Users/George/Downloads/data4P/Customer_list.xlsx")
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0      Chickie    Brister    Male                                   86
# 1        Morly     Genery    Male                                   69
# 2      Ardelis  Forrester  Female                                   10
# 3       Lucine      Stutt  Female                                   64
# 4      Melinda     Hadlee  Female                                   34
# ..         ...        ...     ...                                  ...
# 995  Ferdinand  Romanetti    Male                                   60
# ...

# %%
KPMG_cus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
# ...

# %%
KPMG_cus['last_name'].isna().sum().sum()
# Out:
# 29

# %%
KPMG_cus = KPMG_cus.drop("Unnamed: 16", axis = 1)
KPMG_cus = KPMG_cus.drop("Unnamed: 17", axis = 1)
KPMG_cus = KPMG_cus.drop("Unnamed: 18", axis = 1)
KPMG_cus = KPMG_cus.drop("Unnamed: 19", axis = 1)
KPMG_cus = KPMG_cus.drop("Unnamed: 20", axis = 1)

# %%
KPMG_cus.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes      14     45 Shopko Center
# ...

# %%
KPMG_cus.isna()
# Out:
#      first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0         False      False   False                                False
# 1         False      False   False                                False
# 2         False      False   False                                False
# 3         False      False   False                                False
# 4         False      False   False                                False
# ..          ...        ...     ...                                  ...
# 995       False      False   False                                False
# 996       False      False   False                                False
# 997       False      False   False                                False
# 998       False      False   False                                False
# 999       False      False   False                                False
#
#        DOB  job_title  job_industry_category  wealth_segment  \
# ...

# %%
KPMG_cus.to_csv("C:/Users/George/Downloads/data4P/KPMG_CL.csv")

# %%
KPMG_demo = pd.read_excel(r"C:/Users/George/Downloads/data4P/KPMG_Cdemo.xlsx")
KPMG_demo
# Out:
# C:\Users\George\AppData\Local\Temp\ipykernel_12928\1312510097.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   KPMG_demo = pd.read_excel(r"C:/Users/George/Downloads/data4P/KPMG_Cdemo.xlsx")
#       customer_id      first_name  last_name  gender  \
# 0               1         Laraine  Medendorp       F
# 1               2             Eli    Bockman    Male
# 2               3           Arlin     Dearle    Male
# 3               4          Talbot        NaN    Male
# 4               5  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 3995         3996         Rosalia   Halgarth  Female
# 3996         3997          Blanch     Nisuis  Female
# 3997         3998          Sarene    Woolley       U
# 3998         3999       Patrizius        NaN    Male
# ...

# %%
KPMG_demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   int64
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   int64
#  5   DOB                                  3913 non-null   datetime64[ns]
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  default                              3698 non-null   object
# ...

# %%
KPMG_demo.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# ...

# %%
KPMG_demo.isna().sum().sum()
KPMG_demo.drop("default", axis = 1)
# Out:
#       customer_id      first_name  last_name  gender  \
# 0               1         Laraine  Medendorp       F
# 1               2             Eli    Bockman    Male
# 2               3           Arlin     Dearle    Male
# 3               4          Talbot        NaN    Male
# 4               5  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 3995         3996         Rosalia   Halgarth  Female
# 3996         3997          Blanch     Nisuis  Female
# 3997         3998          Sarene    Woolley       U
# 3998         3999       Patrizius        NaN    Male
# 3999         4000           Kippy    Oldland    Male
#
#       past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                      93 1953-10-12     Executive Secretary
# 1                                      81 1980-12-16  Administrative Officer
# 2                                      61 1954-01-20      Recruiting Manager
# ...

# %%
import seaborn as sns
sns.distplot(KPMG_demo['tenure'])
# Out:
# C:\Users\George\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='tenure', ylabel='Density'>

# %%
KPMG_demo['tenure'].mean()
# Out:
# 10.65704063378482

# %%
KPMG_demo['tenure'] = KPMG_demo['tenure'].fillna(10.657)
KPMG_demo
# Out:
#       customer_id      first_name  last_name  gender  \
# 0               1         Laraine  Medendorp       F
# 1               2             Eli    Bockman    Male
# 2               3           Arlin     Dearle    Male
# 3               4          Talbot        NaN    Male
# 4               5  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 3995         3996         Rosalia   Halgarth  Female
# 3996         3997          Blanch     Nisuis  Female
# 3997         3998          Sarene    Woolley       U
# 3998         3999       Patrizius        NaN    Male
# 3999         4000           Kippy    Oldland    Male
#
#       past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                      93 1953-10-12     Executive Secretary
# 1                                      81 1980-12-16  Administrative Officer
# 2                                      61 1954-01-20      Recruiting Manager
# ...

# %%
KPMG_demo.dropna(inplace = True)
KPMG_demo
# Out:
#       customer_id first_name  last_name  gender  \
# 0               1    Laraine  Medendorp       F
# 1               2        Eli    Bockman    Male
# 2               3      Arlin     Dearle    Male
# 8               9       Mala       Lind  Female
# 9              10   Fiorenze    Birdall  Female
# ...           ...        ...        ...     ...
# 3992         3993       Andi    Dumelow  Female
# 3993         3994    Stephie      Byars  Female
# 3994         3995      Rusty     Iapico    Male
# 3995         3996    Rosalia   Halgarth  Female
# 3996         3997     Blanch     Nisuis  Female
#
#       past_3_years_bike_related_purchases        DOB  \
# 0                                      93 1953-10-12
# 1                                      81 1980-12-16
# 2                                      61 1954-01-20
# 8                                      97 1973-03-10
# 9                                      49 1988-10-11
# ...                                   ...        ...
# ...

# %%
KPMG_demo.isna().sum().sum()
# Out:
# 0

# %%
sns.histplot(KPMG_demo['tenure'])
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='Count'>

# %%
sns.distplot(KPMG_demo['past_3_years_bike_related_purchases'])
# Out:
# C:\Users\George\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='past_3_years_bike_related_purchases', ylabel='Density'>

# %%
KPMG_demo1 = KPMG_demo.to_csv('C:/Users/George/Downloads/data4P/Customer_demo.csv')
KPMG_demo1

# %%
KPMG_add = pd.read_excel(r"C:/Users/George/Downloads/data4P/KPMG_Cadd.xlsx")
KPMG_add.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
KPMG_add.isna().sum().sum()
# Out:
# 0
